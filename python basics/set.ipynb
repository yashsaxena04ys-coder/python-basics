# %%
A = {1, 2, 3 , 4}
B = {3, 4 , 5 , 6}
C = {6, 7, 8 , 9}

# %%
A | B
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A.intersection(B)
A & B
# Out:
# {3, 4}

# %%
A.difference(B)
# Out:
# {1, 2}

# %%
# removes the common elements
A.symmetric_difference(B)
# Out:
# {1, 2, 5, 6}
