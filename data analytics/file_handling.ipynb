# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/yashsaxena/Desktop/data science/data analytics'

# %%
os.mkdir('mydir')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.mkdir('mydir')
#
# FileExistsError: [Errno 17] File exists: 'mydir'

# %%
os.mkdir('dir1')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.mkdir('dir1')
#
# FileExistsError: [Errno 17] File exists: 'dir1'

# %%
os.chdir('mydir')

# %%
os.getcwd()
# Out:
# '/Users/yashsaxena/Desktop/data science/data analytics/mydir'

# %%
os.mkdir('dir2')

# %%
os.mkdir('dir3')

# %%
os.listdir()
# Out:
# ['dir2', 'dir3']

# %%
os.listdir('..')
# Out:
# ['file_handling.ipynb',
#  'numpy.ipynb',
#  'dir1',
#  'handling_datasets.ipynb',
#  'mydir']

# %%
os.listdir('../../python basics')
# Out:
# ['tuple.ipynb',
#  'conditions.ipynb',
#  'datatypes.ipynb',
#  'set.ipynb',
#  'operators.ipynb',
#  'list.ipynb',
#  'intro.ipynb',
#  'list_comprehension.ipynb',
#  'basic_programs.ipynb',
#  'functions.ipynb',
#  'strings.ipynb',
#  '.git',
#  'lambda.ipynb']

# %%
os.getcwd()
# Out:
# '/Users/yashsaxena/Desktop/data science/data analytics'

# %%
with open('myfile.txt', 'r') as file:
    print(file.read())
# Out:
# chalo ladakh chale
